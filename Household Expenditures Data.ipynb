# %% [markdown]
# <a href="https://colab.research.google.com/github/JAYMAN735/ML-Projects/blob/main/Household%20Expenditures%20Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Jayman Prajapati 008 PDS
import pandas as pd

# %% [markdown]
# For Handling Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# For Ploting graphs and advanced data visualization

# %%
df=pd.read_excel('/content/Household_Expenditures_Data.xlsx')

# %% [markdown]
# load the xlsx file from the google colab's working directory

# %%
df.head(10)
# Out:
#   Household  Groceries  Utilities   Rent  Entertainment
# 0        H1       8500       3000  12000           2000
# 1        H2       9200       2800  11500           2500
# 2        H3       8700       3200  13000           3000
# 3        H4       7800       3100  11000           1800
# 4        H5       9600       2900  12500           2700
# 5        H6       9100       3300  14000           2200
# 6        H7       8900       3000  13500           2400
# 7        H8       8500       3100  11500           2100
# 8        H9       9200       3400  12000           2600
# 9       H10       8800       3000  12500           2300

# %% [markdown]
# this helps us take a quick look at how the data is structured

# %%
df.tail()
# Out:
#   Household  Groceries  Utilities   Rent  Entertainment
# 5        H6       9100       3300  14000           2200
# 6        H7       8900       3000  13500           2400
# 7        H8       8500       3100  11500           2100
# 8        H9       9200       3400  12000           2600
# 9       H10       8800       3000  12500           2300

# %% [markdown]
# this helps  us take a quick look at how data is structured

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Household      10 non-null     object
#  1   Groceries      10 non-null     int64
#  2   Utilities      10 non-null     int64
#  3   Rent           10 non-null     int64
#  4   Entertainment  10 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 532.0+ bytes

# %% [markdown]
# Provides data types, non-null values, and memory usage to understand the dataset

# %%
df.isnull().sum()
# Out:
# Household        0
# Groceries        0
# Utilities        0
# Rent             0
# Entertainment    0
# dtype: int64

# %% [markdown]
# check for missing values in each column

# %%
df.describe()
# Out:
#          Groceries   Utilities          Rent  Entertainment
# count    10.000000    10.00000     10.000000      10.000000
# mean   8830.000000  3080.00000  12350.000000    2360.000000
# std     498.998998   181.35294    944.281032     356.526452
# min    7800.000000  2800.00000  11000.000000    1800.000000
# 25%    8550.000000  3000.00000  11625.000000    2125.000000
# 50%    8850.000000  3050.00000  12250.000000    2350.000000
# 75%    9175.000000  3175.00000  12875.000000    2575.000000
# max    9600.000000  3400.00000  14000.000000    3000.000000

# %% [markdown]
# summary statistics of numerical columns

# %%
df1=df.copy()

# %% [markdown]
# copy the dataset into another variable called df1

# %%
df.drop(columns=['Entertainment'])
# Out:
#   Household  Groceries  Utilities   Rent
# 0        H1       8500       3000  12000
# 1        H2       9200       2800  11500
# 2        H3       8700       3200  13000
# 3        H4       7800       3100  11000
# 4        H5       9600       2900  12500
# 5        H6       9100       3300  14000
# 6        H7       8900       3000  13500
# 7        H8       8500       3100  11500
# 8        H9       9200       3400  12000
# 9       H10       8800       3000  12500

# %% [markdown]
# delete a column from dataset using drop keyword

# %%
sns.countplot(x='Rent',data=df)
plt.title("Count Plot")
plt.show()

# %% [markdown]
# it shows the number of times rent is repeated

# %%
df.shape
# Out:
# (10, 5)

# %% [markdown]
# showing number of rows and columns in the dataset

# %%
df.columns.tolist()
# Out:
# ['Household', 'Groceries', 'Utilities', 'Rent', 'Entertainment']

# %% [markdown]
# displaying column names

# %%
df.dtypes
# Out:
# Household        object
# Groceries         int64
# Utilities         int64
# Rent              int64
# Entertainment     int64
# dtype: object

# %% [markdown]
# provides datatypes of every field

# %%
df.drop(columns=["Household"]).mean().plot(kind="bar")
plt.title("Average Spending per Category")
plt.show()

# %% [markdown]
# it displays the average spending per category

# %%
df.plot(x="Household", y=["Entertainment", "Utilities"], kind="line", marker="o")
plt.title("Entertainment vs Utilities Spending per Household")
plt.ylabel("Amount")
plt.show()

# %% [markdown]
# shows the comparison between Entertainment and Utilities

# %%
df["total"]=df['Groceries']+df['Utilities']+df['Rent']+df['Entertainment']
df
# Out:
#   Household  Groceries  Utilities   Rent  Entertainment  total
# 0        H1       8500       3000  12000           2000  25500
# 1        H2       9200       2800  11500           2500  26000
# 2        H3       8700       3200  13000           3000  27900
# 3        H4       7800       3100  11000           1800  23700
# 4        H5       9600       2900  12500           2700  27700
# 5        H6       9100       3300  14000           2200  28600
# 6        H7       8900       3000  13500           2400  27800
# 7        H8       8500       3100  11500           2100  25200
# 8        H9       9200       3400  12000           2600  27200
# 9       H10       8800       3000  12500           2300  26600

# %% [markdown]
# new column is created which gives the total of each row
